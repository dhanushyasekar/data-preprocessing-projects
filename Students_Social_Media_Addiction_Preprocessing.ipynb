# %% [markdown]
# <div style ="background-color :LIGHTBLUE; color:#145A32;padding:15px;border-radius:10px;text-align:center;font-size:20px;"><b>DATA PREPROCESSING PROJECT</b></div>

# %% [markdown]
# This project demonstrates data preprocessing techniques using Python and Pandas.
#
# Steps performed:
# 1. Data Loading
# 2. Data Inspection
# 3. Handling Missing Values
# 4. Removing Duplicates
# 5. Feature Encoding
# 6. Data Standardization

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>IMPORT LIBRARIES</b>
# </div>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>LOAD DATASET</b>
# </div>

# %%
df = pd.read_csv("Students Social Media Addiction.csv")

print("Dataset Loaded Successfully")
df.head()
# Out:
# Dataset Loaded Successfully
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>UNDERSTANING THE DATA</b>
# </div>

# %%
df.tail(2)
# Out:
#      Student_ID  Age  Gender Academic_Level Country  Avg_Daily_Usage_Hours  \
# 703         704   24    Male       Graduate   Japan                    4.3
# 704         705   19  Female  Undergraduate  Poland                    6.2
#
#     Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 703            Twitter                           No                    7.5
# 704           Facebook                          Yes                    6.3
#
#      Mental_Health_Score Relationship_Status  Conflicts_Over_Social_Media  \
# 703                    8              Single                            2
# 704                    5              Single                            4
#
#      Addicted_Score
# 703               4
# 704               8

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    705 non-null    int64
#  1   Age                           705 non-null    int64
#  2   Gender                        705 non-null    str
#  3   Academic_Level                705 non-null    str
#  4   Country                       705 non-null    str
#  5   Avg_Daily_Usage_Hours         705 non-null    float64
#  6   Most_Used_Platform            705 non-null    str
#  7   Affects_Academic_Performance  705 non-null    str
#  8   Sleep_Hours_Per_Night         705 non-null    float64
#  9   Mental_Health_Score           705 non-null    int64
#  10  Relationship_Status           705 non-null    str
#  11  Conflicts_Over_Social_Media   705 non-null    int64
#  12  Addicted_Score                705 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Academic_Level', 'Country',
#        'Avg_Daily_Usage_Hours', 'Most_Used_Platform',
#        'Affects_Academic_Performance', 'Sleep_Hours_Per_Night',
#        'Mental_Health_Score', 'Relationship_Status',
#        'Conflicts_Over_Social_Media', 'Addicted_Score'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Student_ID                        int64
# Age                               int64
# Gender                              str
# Academic_Level                      str
# Country                             str
# Avg_Daily_Usage_Hours           float64
# Most_Used_Platform                  str
# Affects_Academic_Performance        str
# Sleep_Hours_Per_Night           float64
# Mental_Health_Score               int64
# Relationship_Status                 str
# Conflicts_Over_Social_Media       int64
# Addicted_Score                    int64
# dtype: object

# %%
df.shape
# Out:
# (705, 13)

# %%
df.describe()
# Out:
#        Student_ID         Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000  705.000000             705.000000             705.000000
# mean   353.000000   20.659574               4.918723               6.868936
# std    203.660256    1.399217               1.257395               1.126848
# min      1.000000   18.000000               1.500000               3.800000
# 25%    177.000000   19.000000               4.100000               6.000000
# 50%    353.000000   21.000000               4.800000               6.900000
# 75%    529.000000   22.000000               5.800000               7.700000
# max    705.000000   24.000000               8.500000               9.600000
#
#        Mental_Health_Score  Conflicts_Over_Social_Media  Addicted_Score
# count           705.000000                   705.000000      705.000000
# mean              6.226950                     2.849645        6.436879
# ...

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>MISSING VALUE ANALYSIS</b>
# </div>

# %%
df.isnull()
# Out:
#      Student_ID    Age  Gender  Academic_Level  Country  \
# 0         False  False   False           False    False
# 1         False  False   False           False    False
# 2         False  False   False           False    False
# 3         False  False   False           False    False
# 4         False  False   False           False    False
# ..          ...    ...     ...             ...      ...
# 700       False  False   False           False    False
# 701       False  False   False           False    False
# 702       False  False   False           False    False
# 703       False  False   False           False    False
# 704       False  False   False           False    False
#
#      Avg_Daily_Usage_Hours  Most_Used_Platform  Affects_Academic_Performance  \
# 0                    False               False                         False
# 1                    False               False                         False
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>HANDLEING MISSING VALUES</b>
# </div>

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19       0  Undergraduate  Bangladesh
# 1             2   22       1       Graduate       India
# 2             3   20       0  Undergraduate         USA
# 3             4   18       1    High School          UK
# 4             5   21       1       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20       0  Undergraduate       Italy
# 701         702   23       1       Graduate      Russia
# 702         703   21       0  Undergraduate       China
# 703         704   24       1       Graduate       Japan
# 704         705   19       0  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>CHECKING MISSING VALUES</b>
# </div>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>LABEL ENCODER</b>
# </div>

# %% [markdown]
# Import LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Create Encoder Object

# %%
le = LabelEncoder()

# %% [markdown]
# Applying Encoding to a Column

# %%
df['Gender'] = le.fit_transform(df['Gender'])

# %% [markdown]
# Encoding Multiple Columns

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])
# Out:
# C:\Users\dhanu\AppData\Local\Temp\ipykernel_22924\1426036719.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include='object').columns

# %% [markdown]
# <div style="background-color:#E8F8F5;color:black;padding:8px;text-align:center;font-size:18px;border-radius:8px;">
# <b>DATASET CHECK
# </div>

# %%
df.head()
# Out:
#    Student_ID  Age  Gender  Academic_Level  Country  Avg_Daily_Usage_Hours  \
# 0           1   19       0               2       10                    5.2
# 1           2   22       1               0       39                    2.1
# 2           3   20       0               2      102                    6.0
# 3           4   18       1               1      101                    3.0
# 4           5   21       1               0       18                    4.5
#
#    Most_Used_Platform  Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0                   1                             1                    6.5
# 1                   7                             0                    7.5
# 2                   6                             1                    5.0
# 3                  11                             0                    7.0
# 4                   0                             1                    6.0
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Student_ID  Age  Gender  Academic_Level  Country  Avg_Daily_Usage_Hours  \
# 0             1   19       0               2       10                    5.2
# 1             2   22       1               0       39                    2.1
# 2             3   20       0               2      102                    6.0
# 3             4   18       1               1      101                    3.0
# 4             5   21       1               0       18                    4.5
# ..          ...  ...     ...             ...      ...                    ...
# 700         701   20       0               2       44                    4.7
# 701         702   23       1               0       82                    6.8
# 702         703   21       0               2       20                    5.6
# 703         704   24       1               0       46                    4.3
# 704         705   19       0               2       78                    6.2
#
# ...

# %% [markdown]
# ## Conclusion
#
# The dataset was successfully preprocessed by:
#
# • Handling missing values
# • Removing duplicate records
# • Detecting outliers
# • Encoding categorical variables
#
# The cleaned dataset is now ready for Exploratory Data Analysis (EDA) and Machine Learning.
